# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv(r"D:\Pandas dataset\weatherAUS.csv")
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
ab=dataset[["Location","MinTemp","MaxTemp","Humidity9am","WindGustSpeed","RainToday"]]
ab
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9      NaN         62.0            NaN        No
#
# [145460 rows x 6 columns]

# %%
ab.to_csv("dataset1.csv",index=False)

# %%
data=pd.read_csv("dataset1.csv")

# %%
data
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9      NaN         62.0            NaN        No
#
# [145460 rows x 6 columns]

# %%
a=float(input("Enter the value: "))
data["MinTemp"].fillna(a,inplace=True)
# Out:
# Enter the value: 12.4

# %%
data
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9      NaN         62.0            NaN        No
#
# [145460 rows x 6 columns]

# %%
data["MinTemp"].isnull().any()
# Out:
# False

# %%
a=float(input("Enter the value: "))
data["MaxTemp"].fillna(a,inplace=True)
# Out:
# Enter the value: 40.0

# %%
data
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9     40.0         62.0            NaN        No
#
# [145460 rows x 6 columns]

# %%
data["MaxTemp"].isnull().any()
# Out:
# False

# %%
a=float(input("Enter the value: "))
data["Humidity9am"].fillna(a,inplace=True)
# Out:
# Enter the value: 40.1

# %%
data
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9     40.0         62.0            NaN        No
#
# [145460 rows x 6 columns]

# %%
data["Humidity9am"].isnull().any()
# Out:
# False

# %%
a=float(input("Enter the value: "))
data["WindGustSpeed"].fillna(a,inplace=True)
# Out:
# Enter the value: 50.5

# %%
data
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9     40.0         62.0           50.5        No
#
# [145460 rows x 6 columns]

# %%
data["WindGustSpeed"].isnull().any()
# Out:
# False

# %%
data.isnull().sum()
# Out:
# Location            0
# MinTemp             0
# MaxTemp             0
# Humidity9am         0
# WindGustSpeed       0
# RainToday        3261
# dtype: int64

# %%
data["RainToday"].fillna("Other",inplace=True)

# %%
data
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9     40.0         62.0           50.5        No
#
# [145460 rows x 6 columns]

# %%
data.isnull().any()
# Out:
# Location         False
# MinTemp          False
# MaxTemp          False
# Humidity9am      False
# WindGustSpeed    False
# RainToday        False
# dtype: bool

# %% [markdown]
# # 2)find the location those are having mintemp 3-6 and 15-20

# %%
data
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9     40.0         62.0           50.5        No
#
# [145460 rows x 6 columns]

# %%
d=data.loc[(data["MinTemp"]>=3) & (data["MinTemp"]<=6),("Location","MinTemp")]
d
# Out:
#        Location  MinTemp
# 136      Albury      3.5
# 141      Albury      5.7
# 143      Albury      6.0
# 147      Albury      4.5
# 149      Albury      5.4
# ...         ...      ...
# 145446    Uluru      5.1
# 145450    Uluru      5.2
# 145454    Uluru      3.5
# 145456    Uluru      3.6
# 145457    Uluru      5.4
#
# [14606 rows x 2 columns]

# %%
d["MinTemp"].unique()
# Out:
# array([3.5, 5.7, 6. , 4.5, 5.4, 4.6, 4.2, 5.2, 4.1, 3.2, 4.3, 3.7, 3.6,
#        3. , 5.1, 4.4, 4.7, 5. , 3.9, 3.4, 4.8, 5.9, 3.3, 5.5, 5.8, 5.3,
#        4. , 3.8, 5.6, 3.1, 4.9])

# %%
d1=data.loc[(data["MinTemp"]>=15) & (data["MinTemp"]<=20),("Location","MinTemp")]
d1
# Out:
#        Location  MinTemp
# 4        Albury     17.5
# 11       Albury     15.9
# 12       Albury     15.9
# 21       Albury     17.1
# 23       Albury     15.3
# ...         ...      ...
# 145394    Uluru     18.1
# 145395    Uluru     16.8
# 145396    Uluru     15.8
# 145397    Uluru     18.1
# 145398    Uluru     15.6
#
# [31113 rows x 2 columns]

# %%
d1["MinTemp"].unique()
# Out:
# array([17.5, 15.9, 17.1, 15.3, 16.2, 16.9, 19.7, 16.1, 17. , 17.3, 17.2,
#        17.4, 19.8, 18.6, 19.3, 18.8, 15.7, 18.5, 18.4, 18. , 18.7, 15.5,
#        15. , 15.4, 16. , 16.4, 15.6, 17.8, 16.7, 18.1, 18.3, 18.2, 15.1,
#        17.6, 19.4, 16.3, 19.6, 16.8, 19.2, 17.7, 15.2, 18.9, 17.9, 19.5,
#        16.5, 16.6, 19.9, 15.8, 19.1, 20. , 19. ])

# %% [markdown]
# # 3)find the locaton those are having humidity less than 45 on 9am

# %%
data
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9     40.0         62.0           50.5        No
#
# [145460 rows x 6 columns]

# %%
ab=data.loc[(data["Humidity9am"]<45),("Location","Humidity9am")]
ab
# Out:
#        Location  Humidity9am
# 1        Albury         44.0
# 2        Albury         38.0
# 8        Albury         42.0
# 21       Albury         38.0
# 26       Albury         41.0
# ...         ...          ...
# 145437    Uluru         42.0
# 145438    Uluru         42.0
# 145439    Uluru         38.0
# 145440    Uluru         29.0
# 145441    Uluru         27.0
#
# [17549 rows x 2 columns]

# %%
ab["Humidity9am"].unique()
# Out:
# array([44. , 38. , 42. , 41. , 43. , 33. , 34. , 36. , 40. , 35. , 39. ,
#        37. , 27. , 32. , 20. , 29. , 21. , 40.1, 24. , 25. , 31. , 18. ,
#        23. , 26. , 28. , 30. , 19. , 22. , 17. , 15. ,  9. , 12. , 13. ,
#        16. ,  6. , 10. , 14. , 11. ,  7. ,  8. ,  5. ,  3. ,  2. ,  4. ,
#         0. ,  1. ])

# %% [markdown]
# # 4)find the top 10 locations those Min temp is less 5

# %%
data
# Out:
#        Location  MinTemp  MaxTemp  Humidity9am  WindGustSpeed RainToday
# 0        Albury     13.4     22.9         71.0           44.0        No
# 1        Albury      7.4     25.1         44.0           44.0        No
# 2        Albury     12.9     25.7         38.0           46.0        No
# 3        Albury      9.2     28.0         45.0           24.0        No
# 4        Albury     17.5     32.3         82.0           41.0        No
# ...         ...      ...      ...          ...            ...       ...
# 145455    Uluru      2.8     23.4         51.0           31.0        No
# 145456    Uluru      3.6     25.3         56.0           22.0        No
# 145457    Uluru      5.4     26.9         53.0           37.0        No
# 145458    Uluru      7.8     27.0         51.0           28.0        No
# 145459    Uluru     14.9     40.0         62.0           50.5        No
#
# [145460 rows x 6 columns]

# %%
ab1=data.loc[(data["MinTemp"]<5),("Location","MinTemp")]
ab1
# Out:
#        Location  MinTemp
# 136      Albury      3.5
# 147      Albury      4.5
# 150      Albury      2.1
# 151      Albury      1.8
# 153      Albury      4.6
# ...         ...      ...
# 145448    Uluru      2.3
# 145449    Uluru      2.6
# 145454    Uluru      3.5
# 145455    Uluru      2.8
# 145456    Uluru      3.6
#
# [19031 rows x 2 columns]

# %%
ab1.head(10)
# Out:
#     Location  MinTemp
# 136   Albury      3.5
# 147   Albury      4.5
# 150   Albury      2.1
# 151   Albury      1.8
# 153   Albury      4.6
# 154   Albury      4.2
# 156   Albury      4.1
# 157   Albury      3.2
# 158   Albury      4.3
# 159   Albury      3.7

# %% [markdown]
# # 6)Show the location,min and max temp cols those are having WindGustSpeed in between 30 to 50

# %%
ab2=data.loc[(data["WindGustSpeed"]>=30) & (data["WindGustSpeed"]<=50),("Location","MinTemp","MaxTemp")]
ab2
# Out:
#        Location  MinTemp  MaxTemp
# 0        Albury     13.4     22.9
# 1        Albury      7.4     25.1
# 2        Albury     12.9     25.7
# 4        Albury     17.5     32.3
# 6        Albury     14.3     25.0
# ...         ...      ...      ...
# 145452    Uluru      8.0     20.7
# 145453    Uluru      7.4     20.6
# 145454    Uluru      3.5     21.8
# 145455    Uluru      2.8     23.4
# 145457    Uluru      5.4     26.9
#
# [84267 rows x 3 columns]
