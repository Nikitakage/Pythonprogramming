# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
x= np.array([3,6,9])
y= np.array([10,50,70])

plt.plot(x,y)
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y)
plt.show()

# %%
x = np.array([10,50,90,150])
y= np.array([40,110,180,220])

plt.plot(x,y,'*')
plt.show()

# %%
x = np.array([10,50,90,150])
y= np.array([40,110,180,220])

plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([10,50,90,150])
y= np.array([40,110,180,220])

plt.plot(x,y,'s')
plt.show()

# %%
x = np.array([10,50,90,150])
y= np.array([40,110,180,220])

plt.plot(x,y,'p')
plt.show()

# %%
x = np.array([10,50,90,150])
y= np.array([40,110,180,220])

plt.plot(x,y,'x')
plt.show()

# %%
x = np.array([10,50,90,150])
y= np.array([40,110,180,220])

plt.plot(x,y,'X')
plt.show()

# %%
x=np.array([2,5,9,10,12])
y=np.array([20,40,90,30,180])
x1=np.array([2,6,9,10,12])
y1=np.array([10,25,40,75,280])
plt.plot(x,y,'o')
plt.plot(x1,y1,'P')
plt.show()

# %%
x= np.array([10,50,90,150])
y= np.array([40,110,180,220])
x1= np.array([10,40,90,150])
y2= np.array([60,100,140,180])

plt.plot(x,y,"*")
plt.plot(x1,y2,"s")
plt.show()

# %%
x= np.array([10,50,90,150])
y= np.array([40,110,180,220])
x1= np.array([10,40,90,150])
y2= np.array([60,100,140,180])

plt.plot(x,y)
plt.plot(x1,y2)
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y,color='y')
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y,'red')
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y,color='red',ms='15',marker='o')
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y,color='red',ms='15',marker='o',mfc='blue')
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y,color='red',ms='15',marker='o',mfc='b',mec='black')
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y,color='red',ms='15',marker='o',mfc='b',mec='black',linestyle='--')
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y,color='red',ms='15',marker='o',mfc='b',mec='black',linestyle='dashed')
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y,color='red',ms='15',marker='o',mfc='b',mec='black',linestyle='dashed',linewidth='5')
plt.show()

# %%
x = np.array([10,50,90])
y= np.array([40,110,180])

plt.plot(x,y,color='red',ms='15',marker='o',mfc='b',mec='black',linestyle='dashed',linewidth='5')
plt.grid()
plt.show()
