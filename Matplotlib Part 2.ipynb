# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.grid()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.grid(color='y')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.grid(color='r',axis='x')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.grid(color='r',axis='y')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.grid(color='r',ls='-.',linewidth='3')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)
plt.grid(color='purple',ls='--',linewidth='2')
plt.title("Data")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
# plot 1

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.subplot(1,2,1)
plt.plot(x,y,marker='o',mec='b',color='black')
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Data Science ")


# plot 2


x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.subplot(1,2,2)
plt.plot(x,y,marker='p',mec='r',color='hotpink')
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Machine Learning ")
plt.show()

# %%
# plot 1

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.subplot(2,2,1)
plt.plot(x,y,marker='o',mec='b',color='black')
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Data Science ")


# plot 2


x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.subplot(2,2,2)
plt.plot(x,y,marker='p',mec='r',color='hotpink')
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Machine Learning ")
plt.show()


# plot 3

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.subplot(2,2,3)
plt.plot(x,y,marker='o',mec='b',color='black')
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Data Science ")


# plot 4


x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.subplot(2,2,4)
plt.plot(x,y,marker='p',mec='r',color='hotpink')
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Machine Learning ")
plt.show()

# %%
# plot 1

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.subplot(1,2,1)
plt.plot(x,y,marker='o',mec='b',color='black')
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Data Science ")


# plot 2


x = np.array([80, 90,100,110,120, 125])
y = np.array([240, 260,280,300, 310,330])

plt.subplot(1,2,2)
plt.bar(x,y)
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Machine Learning ")
plt.show()

# %%
# plot 1

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.subplot(1,2,1)
plt.scatter(x,y)
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Data Science ")


# plot 2


x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.subplot(1,2,2)
plt.plot(x,y,marker='p',mec='r',color='hotpink')
plt.grid(color='r',ls='--',linewidth='1')
plt.title("Machine Learning ")
plt.show()
